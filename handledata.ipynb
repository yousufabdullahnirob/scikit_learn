# %%
import pandas as pd

data = {
    "Name": ["John", "Anna", "James", "Linda"],
    "Age": [28, None, 35, None],
    "City": [None, "Paris", "London", "Berlin"]
}

df = pd.DataFrame(data)
print("Original DataFrame:")
print(df)

print("\nMissing Values:")
print(df.isnull().sum())

# Correct way to avoid ChainedAssignmentError
df["Age"] = df["Age"].fillna(df["Age"].mean())
df["City"] = df["City"].fillna(df["City"].mode()[0])

print("\nDataFrame after filling missing values:")
print(df)
print(df.isnull().mean()*100)
# Out:
# Original DataFrame:
#     Name   Age    City
# 0   John  28.0     NaN
# 1   Anna   NaN   Paris
# 2  James  35.0  London
# 3  Linda   NaN  Berlin
#
# Missing Values:
# Name    0
# Age     2
# City    1
# dtype: int64
#
# DataFrame after filling missing values:
#     Name   Age    City
# 0   John  28.0  Berlin
# 1   Anna  31.5   Paris
# 2  James  35.0  London
# 3  Linda  31.5  Berlin
# Name    0.0
# Age     0.0
# City    0.0
# dtype: float64
